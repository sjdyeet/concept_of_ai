# %% [markdown]
# <a href="https://colab.research.google.com/github/sjdyeet/concept_of_ai/blob/main/Worksheet0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]


low = []
moderate = []
high = []


for t1, t2, t3 in time_data:
    for hour in (t1, t2, t3):
        if hour < 3:
            low.append(hour)
        elif 3 <= hour <= 5:
            moderate.append(hour)
        else:
            high.append(hour)


print("data less than 3 hour is: ", low)
print("data between 3-5 hour is ", moderate)
print("data greater than 5 hour is ", high)
# Out:
# data less than 3 hour is:  [2.0, 1.5, 2.5, 2.0, 1.5, 2.5, 1.0, 2.0, 2.0, 1.5, 2.5, 2.5, 2.0, 2.5]
# data between 3-5 hour is  [3.5, 5.0, 3.0, 4.0, 4.5, 3.0, 3.5, 4.5, 3.0, 3.0, 4.0, 4.0, 5.0, 3.5]
# data greater than 5 hour is  [7.0, 6.5, 8.0, 6.0, 9.0, 7.5, 5.5, 6.0, 8.5, 7.0, 7.5, 6.0, 6.0, 8.0, 7.0, 6.5, 7.0]

# %%
low_study_time= len(low)
moderate_study_time= len(moderate)
high_study_time= len(high)
print("number of items in the low study list is ",low_study_time)
print("number of items in the moderate study list is ",moderate_study_time)
print("number of items in the high study list is ",high_study_time)
# Out:
# number of items in the low study list is  14
# number of items in the moderate study list is  14
# number of items in the high study list is  17

# %%
total_minutes=[];
for t1, t2, t3 in time_data:
    for hour in (t1, t2, t3):
        minutes=hour*60
        total_minutes.append(minutes)
print("converted list is", total_minutes)

# %%
time_data = [
(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
(4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
(5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
(3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
(4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
]
study_hours= [];
entertainment_hours=[]
sleep_hours=[]
for study,entertainment,sleep in time_data:
  study_hours.append(study)
  entertainment_hours.append(entertainment)
  sleep_hours.append(sleep)
average_study=sum(study_hours)/len(study_hours)
average_entertainment=sum(entertainment_hours)/len(entertainment_hours)
average_sleep=sum(sleep_hours)/len(sleep_hours)

print("the average study hour is: ",average_study)
print("the average entertainment hour is: ",average_entertainment)
print("the average sleep hour is: ",average_sleep)
# Out:
# the average study hour is:  3.7
# the average entertainment hour is:  2.5
# the average sleep hour is:  7.166666666666667

# %%
import matplotlib.pyplot as plt

plt.scatter(study_hours, sleep_hours, color='green')
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study vs Sleep ")


plt.show()

# %%
def sum_nested_list(nested_list):
    """
    Calculate the sum of all numbers in a nested list.

    Args:
        nested_list (list): A list that may contain integers or other lists of integers.

    Returns:
        int: The total sum of all integers in the nested list, including those in sublists.
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):
            total += sum_nested_list(element)
        else:
            total += element
    return total


nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print("The total sum is:", result)
# Out:
# The total sum is: 36

# %%
def generate_permutations(s):
    """
    Generate all unique permutations of a string recursively.

    Args:
        s (str): Input string.

    Returns:
        list: List of all unique permutations.
    """
    if len(s) == 0:
        return ['']  # Base case: empty string

    permutations = []
    for i, char in enumerate(s):

        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            permutations.append(char + perm)


    return list(set(permutations))



print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['abc', 'cba', 'bca', 'acb', 'bac', 'cab']
# ['aba', 'aab', 'baa']

# %%
# Sample directory structure
directory_structure = {
    "file1.txt": 200,
    "file2.txt": 300,
    "subdir1": {
        "file3.txt": 400,
        "file4.txt": 100
    },
    "subdir2": {
        "subsubdir1": {
            "file5.txt": 250
        },
        "file6.txt": 150
    }
}

def calculate_directory_size(directory):
    """
    Recursively calculate total size of a directory including nested subdirectories.

    Args:
        directory (dict): Dictionary representing files and subdirectories.

    Returns:
        int: Total size in KB.
    """
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):
            total_size += calculate_directory_size(value)
        else:  # It's a file
            total_size += value
    return total_size


total = calculate_directory_size(directory_structure)
print("Total directory size:", total, "KB")
# Out:
# Total directory size: 1400 KB

# %%
def min_coins(coins, amount):
    """
    Find the minimum number of coins needed to make up a given amount using dynamic programming.

    Args:
        coins (list of int): Available coin denominations.
        amount (int): Target amount.

    Returns:
        int: Minimum number of coins needed, or -1 if not possible.
    """

    dp = [float('inf')] * (amount + 1)
    dp[0] = 0


    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    return dp[amount] if dp[amount] != float('inf') else -1

coins = [1, 2, 5]
amount = 11

result = min_coins(coins, amount)
print("Minimum number of coins needed:", result)
# Out:
# Minimum number of coins needed: 3

# %%
def longest_common_subsequence(s1, s2):
    """
    Find the length of the longest common subsequence (LCS) between two strings.

    Args:
        s1 (str): First string.
        s2 (str): Second string.

    Returns:
        int: Length of the LCS.
    """
    m, n = len(s1), len(s2)


    dp = [[0] * (n + 1) for _ in range(m + 1)]


    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    return dp[m][n]

s1 = "abcde"
s2 = "ace"

lcs_length = longest_common_subsequence(s1, s2)
print("Length of Longest Common Subsequence:", lcs_length)
# Out:
# Length of Longest Common Subsequence: 3

# %%
def knapsack(weights, values, capacity):
    """
    Solve the 0/1 Knapsack problem using DP.

    Args:
        weights (list of int): List of item weights.
        values (list of int): List of item values.
        capacity (int): Maximum weight capacity.

    Returns:
        int: Maximum value achievable without exceeding capacity.
    """
    n = len(weights)

    dp = [[0] * (capacity + 1) for _ in range(n + 1)]


    for i in range(1, n + 1):
        for w in range(capacity + 1):
            if weights[i-1] <= w:

                dp[i][w] = max(dp[i-1][w], dp[i-1][w - weights[i-1]] + values[i-1])
            else:
                dp[i][w] = dp[i-1][w]

    return dp[n][capacity]


weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7

max_value = knapsack(weights, values, capacity)
print("Maximum value achievable:", max_value)
# Out:
# Maximum value achievable: 9
